# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/JinkaChandanaJyothi2000/project-ch/master/T1.csv'
data = pd.read_csv(url, error_bad_lines=False)
data
# Out:
#               Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0      01 01 2018 00:00           380.047791          5.311336
# 1      01 01 2018 00:10           453.769196          5.672167
# 2      01 01 2018 00:20           306.376587          5.216037
# 3      01 01 2018 00:30           419.645905          5.659674
# 4      01 01 2018 00:40           380.650696          5.577941
# 5      01 01 2018 00:50           402.391998          5.604052
# 6      01 01 2018 01:00           447.605713          5.793008
# 7      01 01 2018 01:10           387.242188          5.306050
# 8      01 01 2018 01:20           463.651215          5.584629
# 9      01 01 2018 01:30           439.725708          5.523228
# 10     01 01 2018 01:40           498.181702          5.724116
# 11     01 01 2018 01:50           526.816223          5.934199
# 12     01 01 2018 02:00           710.587280          6.547414
# 13     01 01 2018 02:10           655.194275          6.199746
# ...

# %%
data.apply(lambda x:sum(x.isnull()), axis=0)
# Out:
# Date/Time                        0
# LV ActivePower (kW)              0
# Wind Speed (m/s)                 0
# Theoretical_Power_Curve (KWh)    0
# Wind Direction (°)               0
# dtype: int64

# %%
data.dtypes
# Out:
# Date/Time                         object
# LV ActivePower (kW)              float64
# Wind Speed (m/s)                 float64
# Theoretical_Power_Curve (KWh)    float64
# Wind Direction (°)               float64
# dtype: object

# %%
data.boxplot(column='LV ActivePower (kW)')

# %%
data.boxplot(column ='Wind Speed (m/s)')

# %%
data.boxplot(column='Wind Direction (°)')

# %%
data.boxplot(column='Theoretical_Power_Curve (KWh)')

# %%
data['Wind Speed (m/s)'].hist(bins=10)

# %%
data['Wind Direction (°)'].hist(bins=10)

# %%
data['Theoretical_Power_Curve (KWh)'].hist(bins=10)

# %%
data['LV ActivePower (kW)'].hist(bins=10)

# %%
sns.distplot(data[ 'LV ActivePower (kW)'])

# %%
import seaborn as sns

# %%
corr=data.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
sns.pairplot(data)

# %%
sns.distplot(data[ 'Wind Speed (m/s)'])

# %%
x=data[['Wind Speed (m/s)']]
y=data[['LV ActivePower (kW)']]

# %%
model1=sm.OLS(y,x).fit()
predictions=model1.predict(x)
model1. summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     LV ActivePower (kW)   R-squared (uncentered):                   0.868
# Model:                             OLS   Adj. R-squared (uncentered):              0.868
# Method:                  Least Squares   F-statistic:                          3.322e+05
# Date:                 Wed, 17 Jun 2020   Prob (F-statistic):                        0.00
# Time:                         15:38:11   Log-Likelihood:                     -4.0075e+05
# No. Observations:                50530   AIC:                                  8.015e+05
# Df Residuals:                    50529   BIC:                                  8.015e+05
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.plot(x,y, 'o')
plt.ylabel("LV ActivePower (kW)")
plt.xlabel("Wind")
plt.axhline(data['LV ActivePower (kW)'].mean(),color='r',linestyle='-')
sns.regplot(x='Wind Speed (m/s)', y="LV ActivePower (kW)" ,data=data)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
x_train=x_train.values.reshape((-1,1))

# %%
from sklearn import linear_model as lm
model1=lm.LinearRegression()
results=model1.fit(x_train,y_train)
results
accuracy=model1. score(x_train,y_train)

# %%
print("accuracy:", accuracy)
print("intercept:", model1.intercept_)
print("slope:", model1.coef_)
# Out:
# accuracy: 0.833419752884946
# intercept: [-837.69809438]
# slope: [[283.86033191]]

# %%
x_test-x_test.values.reshape((-1,1))
#predictions
predictions=model1.predict(x_test)
plt.scatter(x_test, predictions)

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
x_train=x_train.reshape(-1,1)
y_train_prediction= model1.predict(x_train)

# %%
#x_test=x_test.reshape(-1,1)
y_test_prediction=model1.predict(x_test)

# %%
#model evalluation for the training set
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)
print("the model performance for training set")
print("---------------------------------")
print("rmse is {}".format(rmse_training))
print("r2 secoe {}".format(r2_training))
print("\n")
rmse_testing= (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("the model performance for testing set")
print("--------------------------------")
print("rmse is {}".format(rmse_testing))
print("r2 secoe {}".format(r2_testing))
print('\n')
# Out:
# the model performance for training set
# ---------------------------------
# rmse is 535.0073314341129
# r2 secoe 0.833419752884946
#
#
# the model performance for testing set
# --------------------------------
# rmse is 540.4038780558452
# r2 secoe 0.8321059979108418

# %%
x=data[['Wind Direction (°)']]
y=data[['LV ActivePower (kW)']]

# %%
model2=sm.OLS(y,x).fit()
predictions=model2.predict(x)
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     LV ActivePower (kW)   R-squared (uncentered):                   0.288
# Model:                             OLS   Adj. R-squared (uncentered):              0.288
# Method:                  Least Squares   F-statistic:                          2.041e+04
# Date:                 Wed, 17 Jun 2020   Prob (F-statistic):                        0.00
# Time:                         15:38:28   Log-Likelihood:                     -4.4334e+05
# No. Observations:                50530   AIC:                                  8.867e+05
# Df Residuals:                    50529   BIC:                                  8.867e+05
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.plot(x,y,'o')
plt.ylabel('LV Activepowe (KW)')
plt.xlabel('Wind Speed(m/s)')
plt.axhline(data['LV ActivePower (kW)'].mean(),color='r',linestyle='-')
sns.regplot(x='Wind Direction (°)',y='LV ActivePower (kW)', data=data)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
x_train=x_train.values.reshape((-1,1))
from sklearn import linear_model as lm
model2=lm.LinearRegression()
results =model2.fit(x_train,y_train)
accuracy= model2.score(x_train,y_train)

# %%
print("accuracy:", accuracy)
print("intercept: ", model2.intercept_)
print("slope:", model2.coef_)
# Out:
# accuracy: 0.004166337762908201
# intercept:  [1420.34717371]
# slope: [[-0.90488027]]

# %%
x_test=x_test.values.reshape((-1,1))
#predictions
predictions=model2.predict(x_test)
plt.scatter(x_test,predictions)

# %%
#model evaluation for the training set
rmse_training =(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)
print("the model performance for training set")
print("-----------------------------------------")
print("rese is {}".format(rmse_training))
print("r2 seco {}".format(r2_training))
print("\n")
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing-r2_score(y_test,y_test_prediction)
print("the model performance for testing set")
print("-----------------------------------------")
print("rese is {}".format(rmse_testing))
print("r2 secoe {}".format(r2_testing))
print("\n")
# Out:
# the model performance for training set
# -----------------------------------------
# rese is 535.0073314341129
# r2 seco 0.833419752884946
#
#
# the model performance for testing set
# -----------------------------------------
# rese is 540.4038780558452
# r2 secoe 0.8321059979108418

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
x_train=x_train.reshape(-1,1)
y_train_prediction=model2.predict(x_train)
x_test=x_test.reshape(-1,1)
y_test_prediction=model2.predict(x_test)

# %%
x=x.values.reshape(-1,1)
y_predicted=model2.predict(x)
plt.plot(x,y_predicted, color='r')
plt.show()

# %%
x=data[['Theoretical_Power_Curve (KWh)']]
y=data[['LV ActivePower (kW)']]
model3=sm.OLS(y,x).fit()
predictions=model3.predict(x)
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     LV ActivePower (kW)   R-squared (uncentered):                   0.951
# Model:                             OLS   Adj. R-squared (uncentered):              0.951
# Method:                  Least Squares   F-statistic:                          9.730e+05
# Date:                 Wed, 17 Jun 2020   Prob (F-statistic):                        0.00
# Time:                         15:38:39   Log-Likelihood:                     -3.7590e+05
# No. Observations:                50530   AIC:                                  7.518e+05
# Df Residuals:                    50529   BIC:                                  7.518e+05
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
plt.plot(x,y,'o')
plt.ylabel("LV Active Power")
plt.xlabel("theoretical power curve")
plt.axhline(data['LV ActivePower (kW)'].mean(),color='r',linestyle='-')
sns.regplot(x='Theoretical_Power_Curve (KWh)',y="LV ActivePower (kW)",data=data)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=1)
x_train=x_train.values.reshape((-1,1))
from sklearn import linear_model as lm
model3=lm.LinearRegression()
results=model3.fit(x_train,y_train)
accuracy= model3.score(x_train,y_train)
print("accuracy:", accuracy)
print("intercept:", model3. intercept_)
print("slope:", model3.coef_)
# Out:
# accuracy: 0.9017042988022185
# intercept: [-51.01714138]
# slope: [[0.9102701]]

# %%
x_test=x_test.values.reshape((-1,1))
#predictions
predictions=model3.predict(x_test)
plt.scatter(x_test, predictions)

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error, r2_score
X_train=x_train.reshape(-1,1)
y_train_prediction=model3.predict(x_train)
X_test=x_test.reshape(-1,1)
y_test_prediction=model3.predict(x_test)

# %%
#model evalluation for the training set
rmse_training =(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)
print("the model performance for training set")
print("---------------------------------------")
print("rmse is {}".format(rmse_training))
print("r2 secoe {}".format(r2_training))
print('\n')
rmse_testing =(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("the model performance for testing set")
print("------------------------------------------")
print("rese is {}".format(rmse_testing))
print("r2 secoe {}".format(r2_testing))
print('\n')
# Out:
# the model performance for training set
# ---------------------------------------
# rmse is 410.97484933977927
# r2 secoe 0.9017042988022185
#
#
# the model performance for testing set
# ------------------------------------------
# rese is 406.7931509473499
# r2 secoe 0.904863858808847

# %%
x=x.values.reshape(-1,1)
y_predicted=model3.predict(x)
plt.plot(x,y_predicted, color='r')
plt.show()

# %%
X=data[['Wind Speed (m/s)','Theoretical_Power_Curve (KWh)']]
Y=data['LV ActivePower (kW)']

# %%
model4=sm.OLS(Y,X).fit()
predictions=model4.predict(X)
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     LV ActivePower (kW)   R-squared (uncentered):                   0.951
# Model:                             OLS   Adj. R-squared (uncentered):              0.951
# Method:                  Least Squares   F-statistic:                          4.865e+05
# Date:                 Wed, 17 Jun 2020   Prob (F-statistic):                        0.00
# Time:                         15:39:50   Log-Likelihood:                     -3.7590e+05
# No. Observations:                50530   AIC:                                  7.518e+05
# Df Residuals:                    50528   BIC:                                  7.518e+05
# Df Model:                            2
# Covariance Type:             nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#split data
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,y_test=train_test_split(X,Y, test_size=0.4, random_state=1)
#Y_train,y_test,X_train,x_test=train_test_split(X,Y, test_size=0.4, random_state=1)

# %%
print(X_train)
# Out:
#        Wind Speed (m/s)  Theoretical_Power_Curve (KWh)
# 36             7.239252                    1127.433206
# 1800          13.775060                    3600.000000
# 8442           1.711829                       0.000000
# 15192          7.075427                    1050.307772
# 20759         10.475850                    3054.195110
# 49704          7.622767                    1321.942857
# 3506           8.738145                    1976.745862
# 50444          1.101053                       0.000000
# 11720          6.781123                     920.428369
# 22515         10.558060                    3093.022670
# 40792          5.795276                     558.089409
# 22058          6.062419                     645.247133
# 46786         12.763880                    3593.618417
# 29253          2.099661                       0.000000
# 24468         10.370170                    3001.598651
# 16780          4.437139                     208.811380
# ...

# %%
print(Y_train)
# Out:
# 36       1114.026978
# 1800     3574.583008
# 8442        0.000000
# 15192     952.085876
# 20759    2732.837891
# 49704       0.000000
# 3506        0.000000
# 50444       0.000000
# 11720       0.000000
# 22515    2614.010010
# 40792     474.717896
# 22058     512.887329
# 46786    3579.375000
# 29253       0.000000
# 24468    2488.768066
# 16780     157.432907
# 22911       0.000000
# 44875    2887.337891
# 49136    3602.512939
# 29474       0.000000
# 27553      18.242001
# 6537     2842.966064
# 37248     108.219902
# 35955    3493.214111
# 21088    1321.686035
# 27090     862.471680
# 22259       0.000000
# 6754        0.000000
# 25217    1488.651001
# 8229     3602.583008
#             ...
# 26103     138.036102
# 17137    1214.088989
# 19433    1393.240967
# 24535    1507.829956
# 31959     910.942322
# 27204     593.216187
# 49714       0.000000
# 22926       0.000000
# 37532       0.534533
# 19946     157.181900
# 8444        0.000000
# 35730      98.789589
# ...

# %%
X_train=X_train.iloc[:,:].values
Y_train=Y_train.iloc[:].values

# %%
from sklearn import linear_model as lm
model4=lm.LinearRegression()
results=model4.fit(X_train,Y_train)

# %%
predictions= model4.predict(x_test)
accuracy=model4.score(X_train,Y_train)

# %%
 print('Accuracy of the model', accuracy)
# Out:
# Accuracy of the model 0.9047604206849947

# %%
print('slope',model4.coef_)
print("intercept", model4.intercept_)
# Out:
# slope [45.1495645   0.77904727]
# intercept -196.40890704222215

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_train_prediction=model4.predict(X_train)
y_test_prediction=model4.predict(x_test)

# %%
#model evalluation for the training set
rmse_training=(np.sqrt(mean_squared_error(Y_train,y_train_prediction)))
r2_training=r2_score(Y_train,y_train_prediction)
print("the model performance for training set")
print("--------------------------------------------")
print("rmse is {}".format(rmse_training))
print("r2 secoe {}".format(r2_training))
print("\n")
rmse_testing =(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("the model performance for testing set")
print("------------------------------------------")
print("rmse is {}".format(rmse_testing))
print("r2 secoe {}".format(r2_testing))
print("\n")
# Out:
# the model performance for training set
# --------------------------------------------
# rmse is 404.0845661669035
# r2 secoe 0.9047604206849947
#
#
# the model performance for testing set
# ------------------------------------------
# rmse is 406.98003960475387
# r2 secoe 0.9045124026758444
